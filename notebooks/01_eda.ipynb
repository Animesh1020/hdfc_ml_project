# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../dataset/hdfc_loan_dataset_full_enriched.csv")

# %%
df.head()
# Out:
#       Loan_ID       Bank   Customer_Name  Gender Married  Dependents  \
# 0  HDFC100001  HDFC Bank     Rohan Verma    Male      No           2
# 1  HDFC100002  HDFC Bank     Rohan Verma    Male      No           0
# 2  HDFC100003  HDFC Bank     Aditya Nair  Female     Yes           0
# 3  HDFC100004  HDFC Bank    Ananya Joshi    Male      No           0
# 4  HDFC100005  HDFC Bank  Harpreet Singh    Male     Yes           3
#
#   Education Employment_Status  Applicant_Income  Coapplicant_Income  \
# 0  Graduate          Salaried             56976                   0
# 1  Graduate        Unemployed              1856                   0
# 2  Graduate          Salaried             64553                   0
# 3  Graduate          Salaried             88450                   0
# 4  Graduate     Self-Employed              9539                   0
#
#    Loan_Amount  Loan_Term_Months  Credit_History Property_Area  Age  \
# 0      8031545               360               1         Urban   36
# ...

# %%
df.shape
# Out:
# (1000, 47)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Loan_ID                      1000 non-null   str
#  1   Bank                         1000 non-null   str
#  2   Customer_Name                1000 non-null   str
#  3   Gender                       1000 non-null   str
#  4   Married                      1000 non-null   str
#  5   Dependents                   1000 non-null   int64
#  6   Education                    1000 non-null   str
#  7   Employment_Status            1000 non-null   str
#  8   Applicant_Income             1000 non-null   int64
#  9   Coapplicant_Income           1000 non-null   int64
#  10  Loan_Amount                  1000 non-null   int64
#  11  Loan_Term_Months             1000 non-null   int64
#  12  Credit_History               1000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID                          0
# Bank                             0
# Customer_Name                    0
# Gender                           0
# Married                          0
# Dependents                       0
# Education                        0
# Employment_Status                0
# Applicant_Income                 0
# Coapplicant_Income               0
# Loan_Amount                      0
# Loan_Term_Months                 0
# Credit_History                   0
# Property_Area                    0
# Age                              0
# Loan_Status                      0
# CIBIL_Score                      0
# Annual_Household_Income          0
# Debt_to_Income_Ratio             0
# Purpose_of_Loan                  0
# Existing_EMIs                    0
# Number_of_Previous_Loans         0
# Default_History_Count            0
# Employment_Length_Years          0
# Business_Type                  799
# Asset_Value                      0
# Guarantor                        0
# ...

# %%
df.drop(columns=["Business_Type"], inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID                          0
# Bank                             0
# Customer_Name                    0
# Gender                           0
# Married                          0
# Dependents                       0
# Education                        0
# Employment_Status                0
# Applicant_Income                 0
# Coapplicant_Income               0
# Loan_Amount                      0
# Loan_Term_Months                 0
# Credit_History                   0
# Property_Area                    0
# Age                              0
# Loan_Status                      0
# CIBIL_Score                      0
# Annual_Household_Income          0
# Debt_to_Income_Ratio             0
# Purpose_of_Loan                  0
# Existing_EMIs                    0
# Number_of_Previous_Loans         0
# Default_History_Count            0
# Employment_Length_Years          0
# Asset_Value                      0
# Guarantor                        0
# Co-signer_Relationship         234
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         Dependents  Applicant_Income  Coapplicant_Income   Loan_Amount  \
# count  1000.000000       1000.000000          1000.00000  1.000000e+03
# mean      0.849000      42430.057000          9727.11400  2.216713e+06
# std       0.964951      28133.210769         20568.25945  2.635021e+06
# min       0.000000          0.000000             0.00000  1.884000e+03
# 25%       0.000000      18260.000000             0.00000  3.729465e+05
# 50%       1.000000      40675.500000             0.00000  9.720460e+05
# 75%       2.000000      61037.250000          7956.50000  3.315038e+06
# max       3.000000     149266.000000        123461.00000  1.379096e+07
#
#        Loan_Term_Months  Credit_History          Age  CIBIL_Score  \
# count       1000.000000      1000.00000  1000.000000   1000.00000
# mean         159.132000         0.72300    34.412000    653.01300
# std          127.056704         0.44774     8.572616     73.83654
# ...

# %%
df.columns.tolist()
# Out:
# ['Loan_ID',
#  'Bank',
#  'Customer_Name',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Employment_Status',
#  'Applicant_Income',
#  'Coapplicant_Income',
#  'Loan_Amount',
#  'Loan_Term_Months',
#  'Credit_History',
#  'Property_Area',
#  'Age',
#  'Loan_Status',
#  'CIBIL_Score',
#  'Annual_Household_Income',
#  'Debt_to_Income_Ratio',
#  'Purpose_of_Loan',
#  'Existing_EMIs',
#  'Number_of_Previous_Loans',
#  'Default_History_Count',
#  'Employment_Length_Years',
#  'Asset_Value',
#  'Guarantor',
#  'Co-signer_Relationship',
#  'Monthly_Expense',
#  'Organization_Type',
#  'Region_Branch',
#  'Mobile_Verified',
#  'Email_Verified',
#  'Institutional_Relationships',
#  'Application_Text',
#  'Customer_Feedback',
#  'Agent_Notes',
#  'Loan_to_Annual_Income',
#  'Customer_Sentiment',
#  'Religion',
#  'State',
#  'City',
#  'PIN_Code',
#  'Aadhaar_Synthetic',
#  'Phone_Number',
#  'Email',
#  'Occupation']

# %%
print("\nCategorical Summary:")
display(df.describe(include='object'))
# Out:
# Categorical Summary:
# C:\Users\sujal\AppData\Local\Temp\ipykernel_19336\3745775991.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   display(df.describe(include='object'))
#            Loan_ID       Bank Customer_Name Gender Married Education  \
# count         1000       1000          1000   1000    1000      1000
# unique        1000          1            41      3       2         2
# top     HDFC100001  HDFC Bank  Ananya Joshi   Male     Yes  Graduate
# freq             1       1000            79    651     592       717
#
# ...

# %%
drop_cols = [
    'Bank',
    'Customer_Name',
    'Email',
    'Phone_Number',
    'Aadhaar_Synthetic',
    'PIN_Code',
    'Application_Text',
    'Customer_Feedback',
    'Agent_Notes'
]

df.drop(columns=drop_cols, inplace=True)

# %%
df
# Out:
#         Loan_ID  Gender Married  Dependents Education Employment_Status  \
# 0    HDFC100001    Male      No           2  Graduate          Salaried
# 1    HDFC100002    Male      No           0  Graduate        Unemployed
# 2    HDFC100003  Female     Yes           0  Graduate          Salaried
# 3    HDFC100004    Male      No           0  Graduate          Salaried
# 4    HDFC100005    Male     Yes           3  Graduate     Self-Employed
# ..          ...     ...     ...         ...       ...               ...
# 995  HDFC100996    Male     Yes           1  Graduate          Salaried
# 996  HDFC100997    Male      No           2  Graduate          Salaried
# 997  HDFC100998  Female      No           1  Graduate          Salaried
# 998  HDFC100999  Female      No           2  Graduate          Salaried
# 999  HDFC101000  Female     Yes           0  Graduate     Self-Employed
#
#      Applicant_Income  Coapplicant_Income  Loan_Amount  Loan_Term_Months  \
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Co-signer_Relationship         234
# Gender                           0
# Married                          0
# Dependents                       0
# Loan_ID                          0
# Education                        0
# Employment_Status                0
# Coapplicant_Income               0
# Applicant_Income                 0
# Loan_Term_Months                 0
# Credit_History                   0
# Property_Area                    0
# Loan_Amount                      0
# Loan_Status                      0
# CIBIL_Score                      0
# Annual_Household_Income          0
# Debt_to_Income_Ratio             0
# Purpose_of_Loan                  0
# Existing_EMIs                    0
# Number_of_Previous_Loans         0
# Age                              0
# Default_History_Count            0
# Employment_Length_Years          0
# Asset_Value                      0
# Guarantor                        0
# Monthly_Expense                  0
# Organization_Type                0
# ...

# %%
df['Co-signer_Relationship'] = df['Co-signer_Relationship'].fillna('Unknown')

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Loan_ID                      1000 non-null   str
#  1   Gender                       1000 non-null   str
#  2   Married                      1000 non-null   str
#  3   Dependents                   1000 non-null   int64
#  4   Education                    1000 non-null   str
#  5   Employment_Status            1000 non-null   str
#  6   Applicant_Income             1000 non-null   int64
#  7   Coapplicant_Income           1000 non-null   int64
#  8   Loan_Amount                  1000 non-null   int64
#  9   Loan_Term_Months             1000 non-null   int64
#  10  Credit_History               1000 non-null   int64
#  11  Property_Area                1000 non-null   str
#  12  Age                          1000 non-null   int64
# ...

# %%
df.select_dtypes(include='object').columns.tolist()
# Out:
# C:\Users\sujal\AppData\Local\Temp\ipykernel_19336\3152244773.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include='object').columns.tolist()
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Education',
#  'Employment_Status',
#  'Property_Area',
#  'Loan_Status',
#  'Purpose_of_Loan',
#  'Guarantor',
#  'Co-signer_Relationship',
#  'Organization_Type',
#  'Region_Branch',
#  'Mobile_Verified',
#  'Email_Verified',
#  'Institutional_Relationships',
#  'Customer_Sentiment',
#  'Religion',
#  'State',
#  'City',
#  'Occupation']

# %%
loan_ids = df['Loan_ID']
df.drop(columns=['Loan_ID'], inplace=True)

# %%
df.shape
# Out:
# (1000, 36)

# %%
df.head()
# Out:
#    Gender Married  Dependents Education Employment_Status  Applicant_Income  \
# 0    Male      No           2  Graduate          Salaried             56976
# 1    Male      No           0  Graduate        Unemployed              1856
# 2  Female     Yes           0  Graduate          Salaried             64553
# 3    Male      No           0  Graduate          Salaried             88450
# 4    Male     Yes           3  Graduate     Self-Employed              9539
#
#    Coapplicant_Income  Loan_Amount  Loan_Term_Months  Credit_History  \
# 0                   0      8031545               360               1
# 1                   0       899361               240               1
# 2                   0      2387748                60               1
# 3                   0       658856                12               1
# 4                   0       198671                36               0
#
#   Property_Area  Age Loan_Status  CIBIL_Score  Annual_Household_Income  \
# ...

# %%
loan_ids
# Out:
# 0      HDFC100001
# 1      HDFC100002
# 2      HDFC100003
# 3      HDFC100004
# 4      HDFC100005
#           ...
# 995    HDFC100996
# 996    HDFC100997
# 997    HDFC100998
# 998    HDFC100999
# 999    HDFC101000
# Name: Loan_ID, Length: 1000, dtype: str

# %%
df.nunique().sort_values(ascending=False)
# Out:
# Loan_Amount                    1000
# Annual_Household_Income         945
# Asset_Value                     935
# Applicant_Income                926
# Loan_to_Annual_Income           918
# Monthly_Expense                 892
# Existing_EMIs                   769
# Debt_to_Income_Ratio            626
# Coapplicant_Income              344
# CIBIL_Score                     304
# Age                              44
# City                             29
# Occupation                       18
# Employment_Length_Years          16
# Loan_Term_Months                 11
# State                            10
# Purpose_of_Loan                   7
# Region_Branch                     7
# Co-signer_Relationship            6
# Number_of_Previous_Loans          6
# Organization_Type                 5
# Institutional_Relationships       5
# Religion                          5
# Dependents                        4
# Default_History_Count             4
# Employment_Status                 4
# ...

# %%
drop_cols = [
    'Institutional_Relationships',
    'Religion',
    'City'
]

df.drop(columns=drop_cols, inplace=True)

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"\n{col}")
    print(df[col].nunique())
# Out:
# Gender
# 3
#
# Married
# 2
#
# Education
# 2
#
# Employment_Status
# 4
#
# Property_Area
# 3
#
# Loan_Status
# 2
#
# Purpose_of_Loan
# 7
#
# Guarantor
# 2
#
# Co-signer_Relationship
# 6
#
# Organization_Type
# 5
#
# Region_Branch
# 7
#
# Mobile_Verified
# 2
#
# Email_Verified
# 2
#
# Customer_Sentiment
# 3
#
# State
# 10
#
# Occupation
# 18
# C:\Users\sujal\AppData\Local\Temp\ipykernel_19336\2078998271.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include='object').columns:

# %%
numeric_cols = [
    'Applicant_Income',
    'Loan_Amount',
    'Asset_Value',
    'Debt_to_Income_Ratio',
    'Annual_Household_Income'
]

for col in numeric_cols:
    print(col)
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = ((df[col] < lower) | (df[col] > upper)).sum()

    print("Outliers:", outliers)
# Out:
# Applicant_Income
# Outliers: 3
# Loan_Amount
# Outliers: 61
# Asset_Value
# Outliers: 20
# Debt_to_Income_Ratio
# Outliers: 118
# Annual_Household_Income
# Outliers: 30

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Employment_Status',
#        'Applicant_Income', 'Coapplicant_Income', 'Loan_Amount',
#        'Loan_Term_Months', 'Credit_History', 'Property_Area', 'Age',
#        'Loan_Status', 'CIBIL_Score', 'Annual_Household_Income',
#        'Debt_to_Income_Ratio', 'Purpose_of_Loan', 'Existing_EMIs',
#        'Number_of_Previous_Loans', 'Default_History_Count',
#        'Employment_Length_Years', 'Asset_Value', 'Guarantor',
#        'Co-signer_Relationship', 'Monthly_Expense', 'Organization_Type',
#        'Region_Branch', 'Mobile_Verified', 'Email_Verified',
#        'Loan_to_Annual_Income', 'Customer_Sentiment', 'State', 'Occupation'],
#       dtype='str')

# %%
df.head()
# Out:
#    Gender Married  Dependents Education Employment_Status  Applicant_Income  \
# 0    Male      No           2  Graduate          Salaried             56976
# 1    Male      No           0  Graduate        Unemployed              1856
# 2  Female     Yes           0  Graduate          Salaried             64553
# 3    Male      No           0  Graduate          Salaried             88450
# 4    Male     Yes           3  Graduate     Self-Employed              9539
#
#    Coapplicant_Income  Loan_Amount  Loan_Term_Months  Credit_History  \
# 0                   0      8031545               360               1
# 1                   0       899361               240               1
# 2                   0      2387748                60               1
# 3                   0       658856                12               1
# 4                   0       198671                36               0
#
#   Property_Area  Age Loan_Status  CIBIL_Score  Annual_Household_Income  \
# ...

# %%
df.to_csv(
    "../dataset/hdfc_loan_dataset_cleaned.csv",
    index=False
)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))

sns.countplot(
    x='Loan_Status',
    data=df
)

plt.title('Loan Approval Distribution')
plt.xlabel('Loan Status')
plt.ylabel('Count')

plt.savefig(
    "../visuals/loan_status_distribution.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['Applicant_Income'],
    bins=30,
    kde=True
)

plt.title('Applicant Income Distribution')
plt.xlabel('Applicant Income')
plt.ylabel('Frequency')

plt.savefig(
    "../visuals/income_distribution.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
plt.figure(figsize=(12,8))

numeric_df = df.select_dtypes(
    include=['int64','float64']
)

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap')

plt.savefig(
    "../visuals/correlation_heatmap.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['CIBIL_Score'],
    bins=25,
    kde=True
)

plt.title('CIBIL Score Distribution')
plt.xlabel('CIBIL Score')
plt.ylabel('Frequency')

plt.savefig(
    "../visuals/cibil_score_distribution.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='Existing_EMIs',
    y='Loan_Amount',
    data=df
)

plt.title('EMI vs Loan Amount')
plt.xlabel('Existing EMIs')
plt.ylabel('Loan Amount')

plt.savefig(
    "../visuals/emi_vs_loan_amount.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()
